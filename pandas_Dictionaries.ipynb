# %% [markdown]
# <a href="https://colab.research.google.com/github/Anugrahsr/Assignment/blob/master/pandas_Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dictionaries & Pandas
# [github link](https://github.com/AmoDinho/datacamp-python-data-science-track/blob/master/Intermediate%20Python%20for%20Data%20Science/Chapter%202%20-%20Dictionaries%20%26%20Pandas.py)
# ___

# %% [markdown]
# **Motivation for dictionaries**

# %%
countries = ['spain', 'france', 'germany', 'norway']
capitals = ['madrid', 'paris', 'berlin', 'oslo']

# %% [markdown]
# we need to find the capital of germany
# <br>
#
# *   find index of germany
# *   find the capital to the corresponding index of germany

# %%
#index of germany
countries.index('germany')
# Out:
# 2

# %%
print(capitals[countries.index('germany')])
# uff! thats why we need directories
# Out:
# berlin

# %% [markdown]
# **Create dictionary**

# %%
# From string in countries and capitals, create dictionary europe
europe = { "spain": "madrid","france":"paris","germany":"berlin","norway":"oslo"}

# %%
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo'}

# %% [markdown]
# **Access dictionary**
#
#
# ![key and values](https://study.com/cimages/multimages/16/key-value_pairs.png)

# %%
#printing the keys in dictionary europe
print(europe.keys())
# Out:
# dict_keys(['spain', 'france', 'germany', 'norway'])

# %%
## Print out value that belongs to key 'norway'
print(europe['norway'])
# Out:
# oslo

# %%
#printing values in europe
print(europe.values())
# Out:
# dict_values(['madrid', 'paris', 'berlin', 'oslo'])

# %% [markdown]
# **Adding new entries**

# %%
#Let's add italy to europe
europe['italy'] = 'rome'

# %%
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome'}

# %%
#Add poland to europe
europe['poland'] = 'warsaw'

# %%
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %% [markdown]
# **update and remove **

# %%
europe = {'spain':'madrid', 'france':'paris', 'germany':'bonn',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw',
          'australia':'vienna' }

# %%
#oops germany's capital is wrong...we need to change that

europe['germany'] = 'berlin'
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw', 'australia': 'vienna'}

# %%
print(europe['germany'])
# Out:
# berlin

# %% [markdown]
# *Remove australia*

# %%
#Australia is not in Europe...lets delete it
del(europe['australia'])
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %% [markdown]
# **Dictionary of dictionaries**

# %%
europe = { 'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } }

print(europe)
# Out:
# {'spain': {'capital': 'madrid', 'population': 46.77}, 'france': {'capital': 'paris', 'population': 66.03}, 'germany': {'capital': 'berlin', 'population': 80.62}, 'norway': {'capital': 'oslo', 'population': 5.084}}

# %%
# Print out the capital of spain
print(europe['spain']['capital'])
print(europe['spain']['population'])
# Out:
# madrid
# 46.77

# %% [markdown]
# *Adding sub-dictionaries*

# %%
# Create sub-dictionary data
data = {'capital':'rome','population':59.83}

# %%
# Add data to europe under key 'italy'
europe['italy']= data

# Print europe
print(europe)
# Out:
# {'spain': {'capital': 'madrid', 'population': 46.77}, 'france': {'capital': 'paris', 'population': 66.03}, 'germany': {'capital': 'berlin', 'population': 80.62}, 'norway': {'capital': 'oslo', 'population': 5.084}, 'italy': {'capital': 'rome', 'population': 59.83}}

# %% [markdown]
# **#Dictionary to DataFrame**

# %%
# Pre-defined lists
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]

# %% [markdown]
# **Importing Pandas**

# %%
import pandas as pd

# %%
# Create dictionary my_dict with three key:value pairs: my_dict
# {} dont forget
my_dict={'country':names,'drives_right':dr,'cars_per_cap':cpc}

# %%
# Build a DataFrame cars from my_dict: cars

cars=pd.DataFrame(my_dict)
# Print cars
print(cars)
# Out:
#          country  drives_right  cars_per_cap
# 0  United States          True           809
# 1      Australia         False           731
# 2          Japan         False           588
# 3          India         False            18
# 4         Russia          True           200
# 5        Morocco          True            70
# 6          Egypt          True            45

# %%
trip = pd.DataFrame(europe)

# %%
print(trip)
# Out:
#              spain france germany norway  italy
# capital     madrid  paris  berlin   oslo   rome
# population   46.77  66.03   80.62  5.084  59.83

# %%
# Definition of row_labels
row_labels = ['US', 'AUS', 'JAP', 'IN', 'RU', 'MOR', 'EG']
# Specify row labels of cars
cars.index = row_labels
# Print cars again
print(cars)
# Out:
#            country  drives_right  cars_per_cap
# US   United States          True           809
# AUS      Australia         False           731
# JAP          Japan         False           588
# IN           India         False            18
# RU          Russia          True           200
# MOR        Morocco          True            70
# EG           Egypt          True            45

# %% [markdown]
# **CSV to DataFrame**

# %%
import pandas as pd
# Import the cars.csv data: cars
cars = pd.read_csv('cars.csv')

# Print out cars
print(cars)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-64-32bcf5ed7b3b> in <module>()
#       1 import pandas as pd
#       2 # Import the cars.csv data: cars
# ----> 3 cars = pd.read_csv('cars.csv')
#       4
#       5 # Print out cars
#
# ...

# %%
Square Brackets (1)
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)

# Print out country column as Pandas Series
print(cars['country'])

# %%
# Print out country column as Pandas DataFrame
print(cars[['country']])

# Print out DataFrame with country and drives_right columns
print(cars[['country', 'drives_right']])

# %%
import pandas as pd
cars = pd.read_csv('/content/sample_data/california_housing_test.csv')

# Print out first 3 observations
print(cars[0:3])

# Print out fourth, fifth and sixth observation
print(cars[3:6])
# Out:
#    longitude  latitude  ...  median_income  median_house_value
# 0    -122.05     37.37  ...         6.6085            344700.0
# 1    -118.30     34.26  ...         3.5990            176500.0
# 2    -117.81     33.78  ...         5.7934            270500.0
#
# [3 rows x 9 columns]
#    longitude  latitude  ...  median_income  median_house_value
# 3    -118.36     33.82  ...         6.1359            330000.0
# 4    -119.67     36.33  ...         2.9375             81700.0
# 5    -119.56     36.51  ...         1.6635             67000.0
#
# [3 rows x 9 columns]

# %% [markdown]
# **loco iloc**

# %%
cars
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# https://www.youtube.com/watch?v=zmdjNSmRXF4

# %%
cars.shape
# Out:
# (3000, 9)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
# longitude             3000 non-null float64
# latitude              3000 non-null float64
# housing_median_age    3000 non-null float64
# total_rooms           3000 non-null float64
# total_bedrooms        3000 non-null float64
# population            3000 non-null float64
# households            3000 non-null float64
# median_income         3000 non-null float64
# median_house_value    3000 non-null float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
pd.set_option('display.max_columns', 9)

# %%
cars.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
cars.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
cars[:6]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0
# 5       663.0       204.0         1.6635             67000.0

# %%
cars['total_bedrooms']
# Out:
# 0        661.0
# 1        310.0
# 2        507.0
# 3         15.0
# 4        244.0
#          ...
# 2995     642.0
# 2996    1082.0
# 2997     201.0
# 2998      14.0
# 2999     263.0
# Name: total_bedrooms, Length: 3000, dtype: float64

# %%
cars.total_bedrooms[1:5]
# Out:
# 1    310.0
# 2    507.0
# 3     15.0
# 4    244.0
# Name: total_bedrooms, dtype: float64

# %%
cars
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
cars.loc[[1],'total_bedrooms']
# Out:
# 1    310.0
# Name: total_bedrooms, dtype: float64

# %% [markdown]
# **Slicing is inclusive in dataframe**

# %%
cars.loc[0:5,'total_bedrooms']
# Out:
# 0    661.0
# 1    310.0
# 2    507.0
# 3     15.0
# 4    244.0
# 5    213.0
# Name: total_bedrooms, dtype: float64

# %%
cars.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
cars.loc[0:5, 'longitude':'population']
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
#
#    population
# 0      1537.0
# 1       809.0
# 2      1484.0
# 3        49.0
# 4       850.0
# 5       663.0

# %%
cars.loc[0:5, ['longitude','population']]
# Out:
#    longitude  population
# 0    -122.05      1537.0
# 1    -118.30       809.0
# 2    -117.81      1484.0
# 3    -118.36        49.0
# 4    -119.67       850.0
# 5    -119.56       663.0

# %% [markdown]
# **df.loc[row,columns]**

# %%
#only data of people of age 22
cars.loc[cars.housing_median_age == 22].head()
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 72     -118.06     33.80                22.0       1892.0           442.0
# 79     -122.47     37.99                22.0       7274.0          1002.0
# 142    -117.98     34.10                22.0       5661.0          1209.0
# 196    -121.04     38.95                22.0       1931.0           445.0
# 250    -122.03     37.39                22.0       3280.0           933.0
#
#      population  households  median_income  median_house_value
# 72       1015.0       404.0         4.1379            212500.0
# 79       2468.0       957.0         7.4940            439200.0
# 142      5389.0      1178.0         3.7727            159700.0
# 196      1009.0       407.0         2.7500            153200.0
# 250      1842.0       795.0         4.4107            232700.0

# %% [markdown]
# **iloc uses integrer values**

# %%
cars.iloc[0:2,2:6]
#iloc follow exclusivity
# Out:
#    housing_median_age  total_rooms  total_bedrooms  population
# 0                27.0       3885.0           661.0      1537.0
# 1                43.0       1510.0           310.0       809.0

# %%
cars[0:2]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0

# %%
cars.iloc[0:2,:]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0

# %%
#df uses iloc as defult...try iloc for better readability of code

# %% [markdown]
# ----

# %% [markdown]
# # **Dev developers survey**

# %%
#importing pandas
import pandas as pd

# %%
#importing csv
survey_schema = pd.read_csv('/content/survey_results_schema.csv', index_col='Column')
#setting index as column
survey_result = pd.read_csv('/content/survey_results_public.csv', index_col='Respondent')

# %%
survey_schema.sort_index(ascending=False)
#sorting index
# Out:
#                                                     QuestionText
# Column
# YearsCodePro   How many years have you coded professionally (...
# YearsCode      Including any education, how many years have y...
# WorkWeekHrs     On average, how many hours per week do you work?
# WorkRemote                       How often do you work remotely?
# WorkPlan                 How structured or planned is your work?
# ...                                                          ...
# BlockchainOrg  How is your organization thinking about or imp...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BetterLife     Do you think people born today will have a bet...
# Age1stCode     At what age did you write your first line of c...
# Age            What is your age (in years)? If you prefer not...
#
# [85 rows x 1 columns]

# %%
survey_result.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
survey_schema.loc['WorkRemote', 'QuestionText']
# Out:
# 'How often do you work remotely?'

# %%
survey_schema.sort_index(inplace=True)
#inplace=True make the change to df permanatly

# %%
survey_schema
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
# ...                                                          ...
# WorkPlan                 How structured or planned is your work?
# WorkRemote                       How often do you work remotely?
# WorkWeekHrs     On average, how many hours per week do you work?
# YearsCode      Including any education, how many years have y...
# YearsCodePro   How many years have you coded professionally (...
#
# [85 rows x 1 columns]

# %%
filter = (survey_result['Student'] == 'No')

filter
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4         True
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: Student, Length: 88883, dtype: bool

# %%
survey_result.loc[filter,'EdLevel']
# Out:
# Respondent
# 1                                Primary/elementary school
# 3                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6                 Bachelor’s degree (BA, BS, B.Eng., etc.)
#                                ...
# 86638    Some college/university study without earning ...
# 87352             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88212    Secondary school (e.g. American high school, G...
# 88282    Some college/university study without earning ...
# 88377                            Primary/elementary school
# Name: EdLevel, Length: 65816, dtype: object

# %%
survey_result[survey_result['Student'] == 'No']

# %% [markdown]
# & and
# | or

# %%
filter1 = (survey_result['Student'] == 'No') & (survey_result['Employment'] == 'Employed full-time')
filter2 = (survey_result['Student'] == 'No') | (survey_result['Employment'] == 'Employed full-time')

print(survey_result.loc[filter].shape)
print(survey_result.loc[filter1].shape)
print(survey_result.loc[filter2].shape)
# Out:
# (65816, 84)
# (53739, 84)
# (76517, 84)

# %%
pd.set_option('display.max_columns',85)
#show 85 columns, same can be done to rows

# %%
high_salary = (survey_result['ConvertedComp'] > 70000)

# %%
survey_result[high_salary]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
# 13                             I am a developer by profession      Yes
# 16                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88876                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
# 88879                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
survey_result.loc[high_salary,['Country', 'LanguageWorkedWith']]
# Out:
#                    Country                                 LanguageWorkedWith
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ['United States', 'India', 'Finland']
filt = survey_result['Country'].isin(countries)

# %%
survey_result.loc[filt, 'Country']
# Out:
# Respondent
# 4        United States
# 8                India
# 10               India
# 13       United States
# 15               India
#              ...
# 83862            India
# 84299            India
# 85642    United States
# 86012            India
# 88282    United States
# Name: Country, Length: 30556, dtype: object

# %%
filter4 = survey_result['LanguageWorkedWith'].str.contains('Python', na = False)
#string containing python

# %%
survey_result.loc[filter4, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
survey_result.loc[~filter4, 'LanguageWorkedWith']
# ~ negation of filter
# Out:
# Respondent
# 3                                                 HTML/CSS
# 6                                               Java;R;SQL
# 7                                      HTML/CSS;JavaScript
# 11                                               Other(s):
# 13       Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 52440, dtype: object
